# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
import pandas as pd
import re
import json

url = "https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true"
html = urlopen(url)
time.sleep(5)                                           # waits 5sec until next part is started
data= html.read().decode("UTF-8")                       # UTF-8 > character map

with open('raw.html', 'w', encoding='UTF-8') as f:          # context file > everything happens within    zugriffsmodus w == write #Arguments that you do not specifically name are bound to their position in the brakets. They always have to stand before specificall named arguments
    f.write(data)

soup = BeautifulSoup(data, "html.parser")
    
total_str=soup.find("script", string=re.compile("vaf_game"))         #Every comment seems to include a type of vaf_game so this should work longtime

list_str=str(total_str)

crop=list_str.split('data:')[-1]
crop_complete=crop.removesuffix(', sideChannel: {}});</script>')

comment_list= json.loads(crop_complete)
del comment_list[-1]


comment_table= []

for comment in comment_list:
    row={
        'pk': comment_list[0][0][0][0],
        'Name': comment_list[0][0][1][0],
        #'Stars': comment_list[0][0][2][0],
        'Player_Comment': comment_list[0][0][4],
        'Game_Version': comment_list[0][0][10],
        'Company': comment_list[0][0][7][0],
        'Company_Reply': comment_list[0][0][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][1][0][0],
        'Name': comment_list[0][1][1][0],
        #'Stars': comment_list[0][1][2][0],
        'Player_Comment': comment_list[0][1][4],
        'Game_Version': comment_list[0][1][10],
        'Company': comment_list[0][1][7][0],
        'Company_Reply': comment_list[0][1][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][2][0][0],
        'Name': comment_list[0][2][1][0],
        #'Stars': comment_list[0][2][2][0],
        'Player_Comment': comment_list[0][2][4],
        'Game_Version': comment_list[0][2][10],
        'Company': comment_list[0][2][7][0],
        'Company_Reply': comment_list[0][2][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][3][0][0],
        'Name': comment_list[0][3][1][0],
        #'Stars': comment_list[0][3][2][0],
        'Player_Comment': comment_list[0][3][4],
        'Game_Version': comment_list[0][3][10],
        'Company': comment_list[0][3][7][0],
        'Company_Reply': comment_list[0][3][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][4][0][0],
        'Name': comment_list[0][4][1][0],
        #'Stars': comment_list[0][4][2][0],
        'Player_Comment': comment_list[0][4][4],
        'Game_Version': comment_list[0][4][10],
        'Company': comment_list[0][4][7][0],
        'Company_Reply': comment_list[0][4][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][5][0][0],
        'Name': comment_list[0][5][1][0],
        #'Stars': comment_list[0][5][2][0],
        'Player_Comment': comment_list[0][5][4],
        'Game_Version': comment_list[0][5][10],
        'Company': comment_list[0][5][7][0],
        'Company_Reply': comment_list[0][5][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][6][0][0],
        'Name': comment_list[0][6][1][0],
        #'Stars': comment_list[0][6][2][0],
        'Player_Comment': comment_list[0][6][4],
        'Game_Version': comment_list[0][6][10],
        'Company': comment_list[0][6][7][0],
        'Company_Reply': comment_list[0][6][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][7][0][0],
        'Name': comment_list[0][7][1][0],
        #'Stars': comment_list[0][7][2][0],
        'Player_Comment': comment_list[0][7][4],
        'Game_Version': comment_list[0][7][10],
        'Company': comment_list[0][7][7][0],
        'Company_Reply': comment_list[0][7][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][8][0][0],
        'Name': comment_list[0][8][1][0],
        #'Stars': comment_list[0][8][2][0],
        'Player_Comment': comment_list[0][8][4],
        'Game_Version': comment_list[0][8][10],
        #'Company': comment_list[0][7][7][0],
        #'Company_Reply': comment_list[0][7][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][9][0][0],
        'Name': comment_list[0][9][1][0],
        #'Stars': comment_list[0][9][2][0],
        'Player_Comment': comment_list[0][9][4],
        'Game_Version': comment_list[0][9][10],
        'Company': comment_list[0][9][7][0],
        'Company_Reply': comment_list[0][9][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][10][0][0],
        'Name': comment_list[0][10][1][0],
        #'Stars': comment_list[0][10][2][0],
        'Player_Comment': comment_list[0][10][4],
        'Game_Version': comment_list[0][10][10],
        'Company': comment_list[0][10][7][0],
        'Company_Reply': comment_list[0][10][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][11][0][0],
        'Name': comment_list[0][11][1][0],
        #'Stars': comment_list[0][11][2][0],
        'Player_Comment': comment_list[0][11][4],
        'Game_Version': comment_list[0][11][10],
        'Company': comment_list[0][11][7][0],
        'Company_Reply': comment_list[0][11][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][12][0][0],
        'Name': comment_list[0][12][1][0],
        #'Stars': comment_list[0][12][2][0],
        'Player_Comment': comment_list[0][12][4],
        'Game_Version': comment_list[0][12][10],
        'Company': comment_list[0][12][7][0],
        'Company_Reply': comment_list[0][12][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][13][0][0],
        'Name': comment_list[0][13][1][0],
        #'Stars': comment_list[0][13][2][0],
        'Player_Comment': comment_list[0][13][4],
        'Game_Version': comment_list[0][13][10],
        'Company': comment_list[0][13][7][0],
        'Company_Reply': comment_list[0][13][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][14][0][0],
        'Name': comment_list[0][14][1][0],
        #'Stars': comment_list[0][14][2][0],
        'Player_Comment': comment_list[0][14][4],
        'Game_Version': comment_list[0][14][10],
        'Company': comment_list[0][14][7][0],
        'Company_Reply': comment_list[0][14][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][15][0][0],
        'Name': comment_list[0][15][1][0],
        #'Stars': comment_list[0][15][2][0],
        'Player_Comment': comment_list[0][15][4],
        'Game_Version': comment_list[0][15][10],
        'Company': comment_list[0][15][7][0],
        'Company_Reply': comment_list[0][15][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][16][0][0],
        'Name': comment_list[0][16][1][0],
        #'Stars': comment_list[0][16][2][0],
        'Player_Comment': comment_list[0][16][4],
        'Game_Version': comment_list[0][16][10],
        'Company': comment_list[0][16][7][0],
        'Company_Reply': comment_list[0][16][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][17][0][0],
        'Name': comment_list[0][17][1][0],
        #'Stars': comment_list[0][17][2][0],
        'Player_Comment': comment_list[0][17][4],
        'Game_Version': comment_list[0][17][10],
        'Company': comment_list[0][17][7][0],
        'Company_Reply': comment_list[0][17][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][18][0][0],
        'Name': comment_list[0][18][1][0],
        #'Stars': comment_list[0][18][2][0],
        'Player_Comment': comment_list[0][18][4],
        'Game_Version': comment_list[0][18][10],
        'Company': comment_list[0][18][7][0],
        'Company_Reply': comment_list[0][18][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][19][0][0],
        'Name': comment_list[0][19][1][0],
        #'Stars': comment_list[0][19][2][0],
        'Player_Comment': comment_list[0][19][4],
        'Game_Version': comment_list[0][19][10],
        'Company': comment_list[0][19][7][0],
        'Company_Reply': comment_list[0][19][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][20][0][0],
        'Name': comment_list[0][20][1][0],
        #'Stars': comment_list[0][20][2][0],
        'Player_Comment': comment_list[0][20][4],
        'Game_Version': comment_list[0][20][10],
        'Company': comment_list[0][20][7][0],
        'Company_Reply': comment_list[0][20][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][21][0][0],
        'Name': comment_list[0][21][1][0],
        #'Stars': comment_list[0][21][2][0],
        'Player_Comment': comment_list[0][21][4],
        'Game_Version': comment_list[0][21][10],
        'Company': comment_list[0][21][7][0],
        'Company_Reply': comment_list[0][21][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][22][0][0],
        'Name': comment_list[0][22][1][0],
        #'Stars': comment_list[0][22][2][0],
        'Player_Comment': comment_list[0][22][4],
        'Game_Version': comment_list[0][22][10],
        'Company': comment_list[0][22][7][0],
        'Company_Reply': comment_list[0][22][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][23][0][0],
        'Name': comment_list[0][23][1][0],
        #'Stars': comment_list[0][23][2][0],
        'Player_Comment': comment_list[0][23][4],
        'Game_Version': comment_list[0][23][10],
        #'Company': comment_list[0][23][7][0],
        #'Company_Reply': comment_list[0][23][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][24][0][0],
        'Name': comment_list[0][24][1][0],
        #'Stars': comment_list[0][24][2][0],
        'Player_Comment': comment_list[0][24][4],
        'Game_Version': comment_list[0][24][10],
        'Company': comment_list[0][24][7][0],
        'Company_Reply': comment_list[0][24][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][25][0][0],
        'Name': comment_list[0][25][1][0],
        #'Stars': comment_list[0][25][2][0],
        'Player_Comment': comment_list[0][25][4],
        'Game_Version': comment_list[0][25][10],
        'Company': comment_list[0][25][7][0],
        'Company_Reply': comment_list[0][25][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][26][0][0],
        'Name': comment_list[0][26][1][0],
        #'Stars': comment_list[0][26][2][0],
        'Player_Comment': comment_list[0][26][4],
        'Game_Version': comment_list[0][26][10],
        'Company': comment_list[0][26][7][0],
        'Company_Reply': comment_list[0][26][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][27][0][0],
        'Name': comment_list[0][27][1][0],
        #'Stars': comment_list[0][27][2][0],
        'Player_Comment': comment_list[0][27][4],
        'Game_Version': comment_list[0][27][10],
        'Company': comment_list[0][27][7][0],
        'Company_Reply': comment_list[0][27][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][28][0][0],
        'Name': comment_list[0][28][1][0],
        #'Stars': comment_list[0][28][2][0],
        'Player_Comment': comment_list[0][28][4],
        'Game_Version': comment_list[0][28][10],
        'Company': comment_list[0][28][7][0],
        'Company_Reply': comment_list[0][28][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][29][0][0],
        'Name': comment_list[0][29][1][0],
        #'Stars': comment_list[0][29][2][0],
        'Player_Comment': comment_list[0][29][4],
        'Game_Version': comment_list[0][29][10],
        'Company': comment_list[0][29][7][0],
        'Company_Reply': comment_list[0][29][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][30][0][0],
        'Name': comment_list[0][30][1][0],
        #'Stars': comment_list[0][30][2][0],
        'Player_Comment': comment_list[0][30][4],
        'Game_Version': comment_list[0][30][10],
        #'Company': comment_list[0][30][7][0],
        #'Company_Reply': comment_list[0][30][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][31][0][0],
        'Name': comment_list[0][31][1][0],
        #'Stars': comment_list[0][31][2][0],
        'Player_Comment': comment_list[0][31][4],
        'Game_Version': comment_list[0][31][10],
        'Company': comment_list[0][31][7][0],
        'Company_Reply': comment_list[0][31][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][32][0][0],
        'Name': comment_list[0][32][1][0],
        #'Stars': comment_list[0][32][2][0],
        'Player_Comment': comment_list[0][32][4],
        'Game_Version': comment_list[0][32][10],
        'Company': comment_list[0][32][7][0],
        'Company_Reply': comment_list[0][32][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][33][0][0],
        'Name': comment_list[0][33][1][0],
        #'Stars': comment_list[0][33][2][0],
        'Player_Comment': comment_list[0][33][4],
        'Game_Version': comment_list[0][33][10],
        #'Company': comment_list[0][33][7][0],
        #'Company_Reply': comment_list[0][33][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][34][0][0],
        'Name': comment_list[0][34][1][0],
        #'Stars': comment_list[0][34][2][0],
        'Player_Comment': comment_list[0][34][4],
        'Game_Version': comment_list[0][34][10],
        'Company': comment_list[0][34][7][0],
        'Company_Reply': comment_list[0][34][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][35][0][0],
        'Name': comment_list[0][35][1][0],
        #'Stars': comment_list[0][35][2][0],
        'Player_Comment': comment_list[0][35][4],
        'Game_Version': comment_list[0][35][10],
        'Company': comment_list[0][35][7][0],
        'Company_Reply': comment_list[0][35][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][36][0][0],
        'Name': comment_list[0][36][1][0],
        #'Stars': comment_list[0][36][2][0],
        'Player_Comment': comment_list[0][36][4],
        'Game_Version': comment_list[0][36][10],
        'Company': comment_list[0][36][7][0],
        'Company_Reply': comment_list[0][36][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][37][0][0],
        'Name': comment_list[0][37][1][0],
        #'Stars': comment_list[0][37][2][0],
        'Player_Comment': comment_list[0][37][4],
        'Game_Version': comment_list[0][37][10],
        #'Company': comment_list[0][37][7][0],
        #'Company_Reply': comment_list[0][37][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][38][0][0],
        'Name': comment_list[0][38][1][0],
        #'Stars': comment_list[0][38][2][0],
        'Player_Comment': comment_list[0][38][4],
        'Game_Version': comment_list[0][38][10],
        #'Company': comment_list[0][38][7][0],
        #'Company_Reply': comment_list[0][38][7][1]
    }
    comment_table.append(row)
    row={
        'pk': comment_list[0][39][0][0],
        'Name': comment_list[0][39][1][0],
        #'Stars': comment_list[0][39][2][0],
        'Player_Comment': comment_list[0][39][4],
        'Game_Version': comment_list[0][39][10],
        #'Company': comment_list[0][39][7][0],
        #'Company_Reply': comment_list[0][39][7][1]
    }
    comment_table.append(row)
  
    


df=pd.DataFrame(comment_table)
df

####For some reviews you´d need to click on "full review" on the website in order to see everything because of it´s lenghs!!!!!
####Why doesn´t comment and company work for nr 8? Because there is none?

#data == <class 'str'>
#text == <class 'bs4.element.Tag'>
#lists == <class 'list'>
# Out:
#    pk                Name                                     Player_Comment  \
# 0   g       Ryan Oeschger  I love this game its so good there is not to m...
# 1   g     Carsten Rehders  it is advertised as offline, but it is not. on...
# 2   g           Katy Korp  It's a good game, if it wouldn't start lagging...
# 3   g       M e l a n i e  This game is absolutely the trend because firs...
# 4   g          Lil Hammer  Not bad game. Not that maby ads... unless your...
# 5   g            K_Claire  I am addicted to this game but I absolutely de...
# 6   g        Ann Moormann  Has a serious bug with the cloud saves that ha...
# 7   g                 M B  I only have been playing like 20 mins,and it w...
# 8   g        Doyle Miller  Absolutely love this game! I recommend making ...
# 9   g       Robert Foster  I am on Android v11 and this game crashes as s...
# 10  g          Ash Tailor  The game was good. Now the game constantly fla...
# ...

# %% [markdown]
# # test
# test
