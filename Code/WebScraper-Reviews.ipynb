# %%
import urllib.request		#pip install concat("urllib", number of current version)

my_request = urllib.request.urlopen("https://www.netflix.com/")

my_HTML = my_request.read().decode("utf8").split("\n")

print(my_HTML)

# %%
import urllib.request 
from bs4 
import BeautifulSoup 
import requests 

url = "https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true"
response = requests.get(url)
soup = BeautifulSoup(response.content, html5lib)
spans = soup.find_all("span", "ENTER_Css_CLASS_HERE")
for span in spans:
   print(span.text)
# Out:
#   File "C:\Users\KRISTI~1\AppData\Local\Temp/ipykernel_14304/1565657480.py", line 2
#     from bs4 import BeautifulSoup import requests
#                                   ^
# SyntaxError: invalid syntax

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true"
html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")

review_text= soup.find("div", attrs={"jsname":"fk8dgd"})
for text in soup.find("span",{"jsname":"bN97Pc"}):
    print(text)
print (html)
#review_text= soup.span["jsname"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KRISTI~1\AppData\Local\Temp/ipykernel_11536/4064103462.py in <module>
#       7
#       8 review_text= soup.find("div", attrs={"jsname":"fk8dgd"})
# ----> 9 for text in soup.find("span",{"jsname":"bN97Pc"}):
#      10     print(text)
#      11 print (html)
#
# TypeError: 'NoneType' object is not iterable

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

def main():
    # ...
  
        url = f"https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true"
        print(url)
        with urlopen(url) as response:
            html = response.read()

        review_text= soup.find("div", attrs={"class":"fk8dgd"})
        for text in soup("span",{"jsname":"bN97Pc"}):
             print(text)


#if __name__ == "__main__":
   # main()

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
import pandas as pd
import re

url = "https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true"
html = urlopen(url)
time.sleep(5)                                           # waits 5sec until next part is started
data= html.read().decode("UTF-8")                       # UTF-8 > character map

with open('raw.html', 'w', encoding='UTF-8') as f:          # context file > everything happens within    zugriffsmodus w == write #Arguments that you do not specifically name are bound to their position in the brakets. They always have to stand before specificall named arguments
    f.write(data)

soup = BeautifulSoup(data, "html.parser")

#text=soup.find_all('div', attrs={'class':'UD7Dzf'})
#print(data)
    
text_part=soup.find("script", string=re.compile("Ryan"))         #This won´t work if enough people write comments and "Ryan" won´t be seen on the first page anymore


lists=str(text_part).split(",")                                  #split() converts into a list. Would split on spaces by default

#comment= re.match(r'"/b',lists)

matches= []

for match in lists:
    if '"' in match:
        matches.append(match)
print(matches)


#data == <class 'str'>
#text == <class 'bs4.element.Tag'>
#lists == <class 'list'>
# Out:
# ['<script nonce="z4Ng8aaWLfRg5OkNxn5wSQ">AF_initDataCallback({key: \'ds:18\'', ' data:[[["gp:AOqpTOFwLsL9ahWkUT2wTjbHmEYckxD6v6c5AukldiusyGkobXAMFMDfhXGEKxM78f2w44b6V09kifu-JKeNtw"', '["Ryan Oeschger"', '"https://play-lh.googleusercontent.com/a-/AOh14Gh8aEt_G6czS81_33FSKZAT8NKQQ_i9gg4Yp5en"]]]', '"I love this game its so good there is not to many ads either its perfect."', '["101730272282518688470"', '"Ryan Oeschger"', '"https://play-lh.googleusercontent.com/a-/AOh14Gh8aEt_G6czS81_33FSKZAT8NKQQ_i9gg4Yp5en"]]', '"https://play-lh.googleusercontent.com/Yq7oyNIvAAkuc69fG51sbAQS4otJxbObbt3xdr8tXxXyUdq4tVGtfgeKuptveGdP1srxaHVrNPzOYcfaEQ"]]]', '"3.69.0"', '[[["vaf_never_display_difficult_to_use"', '["vaf_games_genre_base_building"', '["vaf_games_subject_track_and_field"', '["gp:AOqpTOEAHLa6_rmnqoZI-2tYKZZj1ctaf8lDRenDeH5VbFmWe3g2hHmOLNY9LdVjApArJ-cRT6XjCAyDz_9FXg"', '["Carsten Rehders"', '"https://play-lh.googleusercontent.com/a/AATXAJx8dVXpOuLAa8tmQyuxktaUPZhamIZYGdiQ3CXr\\u003dmo"]]]', '"it is advertised as offline', ' but it is not. on every click it tries to connect to some server and blocks game until seemingly running into a connection timeout after 30 seconds. not funny."', '["Kolibri Games"', '"Hello! We would really like to give you some help with your concerns - could you send us more information to community@idleminertycoon.com so we can talk with you directly? Thanks in advance!"', '["112660907985210245397"', '"Carsten Rehders"', '"https://play-lh.googleusercontent.com/a/AATXAJx8dVXpOuLAa8tmQyuxktaUPZhamIZYGdiQ3CXr\\u003dmo"]]', '"https://play-lh.googleusercontent.com/Yq7oyNIvAAkuc69fG51sbAQS4otJxbObbt3xdr8tXxXyUdq4tVGtfgeKuptveGdP1srxaHVrNPzOYcfaEQ"]]]', '"3.63.0"', '[[["vaf_games_subject_train"]', '["vaf_games_massively_multi_player"]', '["vaf_games_genre_motor_sports"]]]]', '["gp:AOqpTOHUHfAvdp03sfYd3QMt2rM26tVIb4TZ6B6EroalbQLG2p_OD1xYz0deGuwfyAS_JhN38RlWhga0-xXRLA"', '["Katy Korp"', '"https://play-lh.googleusercontent.com/a/AATXAJxpEELHDVQi8YFJl_J4dciV4iNoJUIxKrjfgSQI\\u003dmo"]]]', '"It\'s a good game', ' let lone use a super manager"', '["Kolibri Games"', '"Hello there Katy! Could you possibly e-mail us at community@idleminertycoon.com so we can get more information from you and help you further with this? We would appreciate it!"', '["104126464024028590377"', '"Katy Korp"', '"https://play-lh.googleusercontent.com/a/AATXAJxpEELHDVQi8YFJl_J4dciV4iNoJUIxKrjfgSQI\\u003dmo"]]', '"https://play-lh.googleusercontent.com/Yq7oyNIvAAkuc69fG51sbAQS4otJxbObbt3xdr8tXxXyUdq4tVGtfgeKuptveGdP1srxaHVrNPzOYcfaEQ"]]]', '"3.65.0"', '[[["vaf_games_subject_dentist"]', '["vaf_games_genre_endless_runners"]', '["vaf_never_display_negative_ads_impact"]]]]', '["gp:AOqpTOFDjV-btw6OI-2_5JPMEvrlv-kwIB1k3fQZy9_Ot2E1_RLfPyVimrdWaC4oR59uapprBPI3VMr6YOP5Vg"', '["M e l a n i e"', '"https://play-lh.googleusercontent.com/a-/AOh14GintuH5AXe_aOUWSiNnTTZPg2wUm8vtEKQQ25FriA"]]]', '"This game is absolutely the trend because first it\'s so fun to play I just.... I just have no words and the best thing is you in Germany and I\'m a German too and I live in German you can speak German with me! Einfach geiles spiel 5 Sterne🍁🍂🕯️🎃 happy Halloween!"', '["Kolibri Games"', '"Superlieben Dank für deine Rezension! ❤️ Schreib uns jederzeit gerne unter community@idleminertycoon.com an', ' falls du noch mehr Vorschläge zur Verbesserung des Spiels hast!"', '["117111008749525246534"', '"M e l a n i e"', '"https://play-lh.googleusercontent.com/a-/AOh14GintuH5AXe_aOUWSiNnTTZPg2wUm8vtEKQQ25FriA"]]', '"https://play-lh.googleusercontent.com/Yq7oyNIvAAkuc69fG51sbAQS4otJxbObbt3xdr8tXxXyUdq4tVGtfgeKuptveGdP1srxaHVrNPzOYcfaEQ"]]]', '"3.64.0"', '[[["vaf_games_genre_endless_runners"]', '["vaf_games_subject_talking_animals"]', '["vaf_never_display_negative_ads_impact"]]]', '["gp:AOqpTOG2aVnvM-APbY73w_hwG_xB8Ff32fFCtaV66tyvlveQ9dF43bxzCyuHXKSboJ3VFD8l-Yjcpag_eqGZ_g"', '["Lil Hammer"', '"https://play-lh.googleusercontent.com/a/AATXAJyU_0J_y5KtNfETNDgAqgVFqbbZL1545q1H9tFY\\u003dmo"]]]', ' ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
#import dryscrape

url = "https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true"
html = urlopen(url)
time.sleep(5)                                           # waits 5sec until next part is started
data= html.read().decode("UTF-8")                       # UTF-8 > character map
soup = BeautifulSoup(data, "html.parser")

with open('raw2.html', 'w', encoding='UTF-8') as f:          # context file > everything happens within    zugriffsmodus w == write #Arguments that you do not specifically name are bound to their position in the brakets. They always have to stand before specificall named arguments
    f.write(data)

result = soup.find_all(lambda tag: tag.name == 'script' and 
                                   tag.get('nonce') == ['Ywd3ciS1xxauJ+mRZG9Swg'])
print(result)
# Out:
# []

# %%
import urllib.request
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd


# specify the url
urlpage = 'https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true' 
print(urlpage)
# run firefox webdriver from executable path of your choice
driver = webdriver.Chrome(executable_path = 'C:\Users\KristinMoewes\Documents\Python\Python')
# Out:
#   File "C:\Users\KRISTI~1\AppData\Local\Temp/ipykernel_17156/2361306613.py", line 12
#     driver = webdriver.Chrome(executable_path = 'C:\Users\KristinMoewes\Documents\Python\Python')
#                                                                                                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# # test
# test
