# %%
import urllib.request		#pip install concat("urllib", number of current version)

my_request = urllib.request.urlopen("https://www.netflix.com/")

my_HTML = my_request.read().decode("utf8").split("\n")

print(my_HTML)

# %%
import urllib.request 
from bs4 
import BeautifulSoup 
import requests 

url = "https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true"
response = requests.get(url)
soup = BeautifulSoup(response.content, html5lib)
spans = soup.find_all("span", "ENTER_Css_CLASS_HERE")
for span in spans:
   print(span.text)
# Out:
#   File "C:\Users\KRISTI~1\AppData\Local\Temp/ipykernel_14304/1565657480.py", line 2
#     from bs4 import BeautifulSoup import requests
#                                   ^
# SyntaxError: invalid syntax

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true"
html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")

review_text= soup.find("div", attrs={"jsname":"fk8dgd"})
for text in soup.find("span",{"jsname":"bN97Pc"}):
    print(text)
print (html)
#review_text= soup.span["jsname"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KRISTI~1\AppData\Local\Temp/ipykernel_11536/4064103462.py in <module>
#       7
#       8 review_text= soup.find("div", attrs={"jsname":"fk8dgd"})
# ----> 9 for text in soup.find("span",{"jsname":"bN97Pc"}):
#      10     print(text)
#      11 print (html)
#
# TypeError: 'NoneType' object is not iterable

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

def main():
    # ...
  
        url = f"https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true"
        print(url)
        with urlopen(url) as response:
            html = response.read()

        review_text= soup.find("div", attrs={"class":"fk8dgd"})
        for text in soup("span",{"jsname":"bN97Pc"}):
             print(text)


#if __name__ == "__main__":
   # main()

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
import pandas as pd
import re

url = "https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true"
html = urlopen(url)
time.sleep(5)                                           # waits 5sec until next part is started
data= html.read().decode("UTF-8")                       # UTF-8 > character map

with open('raw.html', 'w', encoding='UTF-8') as f:          # context file > everything happens within    zugriffsmodus w == write #Arguments that you do not specifically name are bound to their position in the brakets. They always have to stand before specificall named arguments
    f.write(data)

soup = BeautifulSoup(data, "html.parser")

#text=soup.find_all('div', attrs={'class':'UD7Dzf'})
#print(data)
    
text_part=soup.find("script", string=re.compile("Ryan"))         #This won´t work if enough people write comments and "Ryan" won´t be seen on the first page anymore


lists=str(text_part).split(",")                                  #split() converts into a list. Would split on spaces by default

#comment= re.match(r'"/b',lists)

matches= []

for match in lists:
    if '"' in match:
        matches.append(match)
print(matches)


#with open(list_str, 'r') as j_list:
    # contents = json.loads(j_list.read())

for lists in list_str:
    lists = json.loads(list_str)
    print(json.loads(list_str))
  
    # 
    # 


#data == <class 'str'>
#text == <class 'bs4.element.Tag'>
#lists == <class 'list'>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
#import dryscrape

url = "https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true"
html = urlopen(url)
time.sleep(5)                                           # waits 5sec until next part is started
data= html.read().decode("UTF-8")                       # UTF-8 > character map
soup = BeautifulSoup(data, "html.parser")

with open('raw2.html', 'w', encoding='UTF-8') as f:          # context file > everything happens within    zugriffsmodus w == write #Arguments that you do not specifically name are bound to their position in the brakets. They always have to stand before specificall named arguments
    f.write(data)

result = soup.find_all(lambda tag: tag.name == 'script' and 
                                   tag.get('nonce') == ['Ywd3ciS1xxauJ+mRZG9Swg'])
print(result)
# Out:
# []

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import time
import pandas as pd
import re
import json

url = "https://play.google.com/store/apps/details?id=com.fluffyfairygames.idleminertycoon&gl=DE&showAllReviews=true"
html = urlopen(url)
time.sleep(5)                                           # waits 5sec until next part is started
data= html.read().decode("UTF-8")                       # UTF-8 > character map

with open('raw.html', 'w', encoding='UTF-8') as f:          # context file > everything happens within    zugriffsmodus w == write #Arguments that you do not specifically name are bound to their position in the brakets. They always have to stand before specificall named arguments
    f.write(data)

soup = BeautifulSoup(data, "html.parser")
    
total_str=soup.find("script", string=re.compile("vaf_game"))         #Every comment seems to include a type of vaf_game so this should work longtime

list_str=str(total_str)

crop=list_str.split('data:')[-1]
crop_complete=crop.removesuffix(', sideChannel: {}});</script>')

list= json.loads(crop_complete)

df = pd.DataFrame(list, columns=['GP', 'Name', 'X', 'X', 'X', 'X', 'X', 'X', 'Stars', 'X', 'Comment', 'X', 'X', 'X', 'X', 'X', 'X', 'Name2', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'Version', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X', 'X'])

print(df)




#data == <class 'str'>
#text == <class 'bs4.element.Tag'>
#lists == <class 'list'>
# Out:
#                                                   GP  \
# 0  [gp:AOqpTOFwLsL9ahWkUT2wTjbHmEYckxD6v6c5Aukldi...
# 1                                               None
#
#                                                 Name  \
# 0  [gp:AOqpTOEAHLa6_rmnqoZI-2tYKZZj1ctaf8lDRenDeH...
# 1  CpIBCo8BKmkKR_8AwEEuhIGtiVQA___-9zuazUf__vy-mJ...
#
#                                                    X  \
# 0  [gp:AOqpTOHUHfAvdp03sfYd3QMt2rM26tVIb4TZ6B6Ero...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOFDjV-btw6OI-2_5JPMEvrlv-kwIB1k3fQZy9...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOG2aVnvM-APbY73w_hwG_xB8Ff32fFCtaV66t...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOG6b7fRf0UtZf5mWCIgSHi1U8VoX_MxoWtDHC...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOGawifGte_wrSVwM7N6Yl1KztQhgT5wZKXdmt...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOEtKtWgXhoDrpi4fmhIKN6tR86j_jJlTTRd9f...
# 1                                               None
#
#                                                Stars  \
# 0  [gp:AOqpTOF5xX4wrUACbuTQWBTTsIoye_b8gTj_OBkSOF...
# 1                                               None
#
#                                                    X  ...  \
# 0  [gp:AOqpTOGZJcvSnQuYG-1YOZqCyfas8jSIx3SJsqZGnX...  ...
# 1                                               None  ...
#
#                                                    X  \
# 0  [gp:AOqpTOHt1idP_0MooIz-uw1ilwzZP7vhqgIrwmMFQe...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOEVyQwn4MVFPETNJTY5e1KfgeAKjkYF40bklh...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOGHrn0AKf4N0IL9d1ES9jWKNeOYuW-7UPxeO4...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOGpXMbf0Gis6n1_RmjTntle-tfPV2A83Cu1Ym...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOHo5y1qFNtWOCTPisTAKKskfSbFW93PZi7f5U...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOHXBzgNBUpyepblgXzqHK1I7ZBtRxCA_jEKx3...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOHXqNNFnPyrAJUmJSMuuO9sM0vpj02PKzSWYo...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOGmOLBAQDDn_NY5kESon5qNbixvTUC1K92mbN...
# 1                                               None
#
#                                                    X  \
# 0  [gp:AOqpTOESmrQoa-vqFMbVaceS2lBwOJWkbHO800fzwb...
# 1                                               None
#
#                                                    X
# 0  [gp:AOqpTOFluUKTJrjtSlrDrifOClZGm1jeWUWS_ZDdhp...
# 1                                               None
#
# [2 rows x 40 columns]

# %% [markdown]
# # test
# test
